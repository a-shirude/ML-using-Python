# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

books = pd.read_csv('BX-Books.csv',  encoding="latin-1")

users = pd.read_csv('BX-Users.csv',  encoding="latin-1")

ratings = pd.read_csv('BX-Book-Ratings.csv',  encoding="latin-1", nrows=100000)
# Out:
# c:\users\akshaysh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3050: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\users\akshaysh\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3050: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(ratings.shape)
# Out:
# (100000, 3)

# %%
ratings.head()
# Out:
#    user_id        isbn  rating
# 0   276725  034545104X       0
# 1   276726   155061224       5
# 2   276727   446520802       0
# 3   276729  052165615X       3
# 4   276729   521795028       6

# %%
plt.rc("font",size=15)
ratings.rating.value_counts(sort=False).plot(kind="bar")
plt.title("Rating_xAxis vs Count_yAxis")
plt.show()

# %%
print(books.shape)
print(list(books.columns))
books.head()
# Out:
# (271379, 5)
# ['isbn', 'book_title', 'book_author', 'year_of_publication', 'publisher']
#         isbn                                         book_title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             book_author year_of_publication                   publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
print(users.shape)
print(list(users.columns))
users.head()
# Out:
# (278859, 3)
# ['user_id', 'Location', 'Age']
#   user_id                            Location   Age
# 0       1                  nyc, new york, usa   NaN
# 1       2           stockton, california, usa  18.0
# 2       3     moscow, yukon territory, russia   NaN
# 3       4           porto, v.n.gaia, portugal  17.0
# 4       5  farnborough, hants, united kingdom   NaN

# %%
users.Age.hist(bins=[0,10,20,30,40,50,100])
plt.title("Age Distribution")
plt.show()

# %%
rating_count=pd.DataFrame(ratings.groupby('isbn')['rating'].count())
rating_count.sort_values('rating',ascending=False).head()
# Out:
#            rating
# isbn
# 971880107     197
# 316666343     107
# 385504209      76
# 60928336       69
# 312195516      64

# %%
most_rated_books=pd.DataFrame(['971880107','316666343','385504209','312195516','60928336'], index=np.arange(5),columns=['isbn'])
most_rated_books_summary=pd.merge(most_rated_books,books,on='isbn')
most_rated_books_summary
# Out:
#         isbn                                       book_title    book_author  \
# 0  971880107                                      Wild Animus   Rich Shapero
# 1  316666343                        The Lovely Bones: A Novel   Alice Sebold
# 2  385504209                                The Da Vinci Code      Dan Brown
# 3  312195516              The Red Tent (Bestselling Backlist)  Anita Diamant
# 4   60928336  Divine Secrets of the Ya-Ya Sisterhood: A Novel  Rebecca Wells
#
#   year_of_publication      publisher
# 0                2004        Too Far
# 1                2002  Little, Brown
# 2                2003      Doubleday
# 3                1998    Picador USA
# 4                1997      Perennial

# %%
average_rating = pd.DataFrame(ratings.groupby('isbn')['rating'].mean())
average_rating['ratingCount'] = pd.DataFrame(ratings.groupby('isbn')['rating'].count())
average_rating.sort_values('ratingCount', ascending=False).head()
# Out:
#              rating  ratingCount
# isbn
# 971880107  0.954315          197
# 316666343  4.504673          107
# 385504209  5.210526           76
# 60928336   4.057971           69
# 312195516  4.484375           64

# %%
counts1 = ratings['user_id'].value_counts()
ratings = ratings[ratings['user_id'].isin(counts1[counts1 >= 200].index)]

counts = ratings['rating'].value_counts()
ratings = ratings[ratings['rating'].isin(counts[counts >= 100].index)]

# %%
ratings_pivot = ratings.pivot_table(index='user_id', columns='isbn').rating
user_id = ratings_pivot.index
isbn = ratings_pivot.columns
print(ratings_pivot.shape)
ratings_pivot.head()
# Out:
# (64, 36200)
# isbn      0  0 7336 1053 6  000217877X  000225929X  0006093090X  000617843X  \
# user_id
# 254     NaN            NaN         NaN         NaN          NaN         NaN
# 2276    NaN            NaN         NaN         NaN          NaN         NaN
# 2766    NaN            NaN         NaN         NaN          NaN         NaN
# 2977    NaN            NaN         NaN         NaN          NaN         NaN
# 3363    NaN            NaN         NaN         NaN          NaN         NaN
#
# isbn     000617891X  0006392172PBK  000647506X  000648302X  ...  O439060737  \
# user_id                                                     ...
# 254             NaN            NaN         NaN         NaN  ...         NaN
# 2276            NaN            NaN         NaN         NaN  ...         NaN
# 2766            NaN            NaN         NaN         NaN  ...         NaN
# 2977            NaN            NaN         NaN         NaN  ...         NaN
# 3363            NaN            NaN         NaN         NaN  ...         NaN
#
# isbn     O446611638  O451203771  O77O428452  O805063196  O9088446X  \
# user_id
# 254             NaN         NaN         NaN         NaN        NaN
# 2276            NaN         NaN         NaN         NaN        NaN
# 2766            NaN         NaN         NaN         NaN        NaN
# 2977            NaN         NaN         NaN         NaN        NaN
# 3363            NaN         NaN         NaN         NaN        NaN
#
# isbn     X000000000  ZR903CX0003  \0432534220\""  \2842053052\""
# user_id
# 254             NaN          NaN             NaN             NaN
# 2276            NaN          NaN             NaN             NaN
# 2766            NaN          NaN             NaN             NaN
# 2977            NaN          NaN             NaN             NaN
# 3363            NaN          NaN             NaN             NaN
#
# [5 rows x 36200 columns]

# %%
bones_ratings = ratings_pivot['316666343']
similar_to_bones = ratings_pivot.corrwith(bones_ratings)
corr_bones = pd.DataFrame(similar_to_bones, columns=['pearsonR'])
corr_bones.dropna(inplace=True)
corr_summary = corr_bones.join(average_rating['ratingCount'])
corr_summary[corr_summary['ratingCount']>=0].sort_values('pearsonR', ascending=False).head(10)
# Out:
#            pearsonR  ratingCount
# isbn
# 156006847       1.0            6
# 762406984       1.0            5
# 425176088       1.0            4
# 767905385       1.0           11
# 767915054       1.0           13
# 785799524       1.0            2
# 425185249       1.0            2
# 307016277       1.0            2
# 786710829       1.0            2
# 425191796       1.0            2

# %%
books_corr_to_bones = pd.DataFrame(['156006847', '762406984', '425176088', '767915054', '767905385'], 
                                  index=np.arange(5), columns=['isbn'])
corr_books = pd.merge(books_corr_to_bones, books, on='isbn')
corr_books
# Out:
#         isbn                                         book_title  \
# 0  156006847                        The Fencing Master: A Novel
# 1  762406984  The World's Shortest Stories of Love and Death...
# 2  425176088                                            Airport
# 3  767915054  A Girl Named Zippy: Growing Up Small in Moorel...
# 4  767905385  Catch Me If You Can: The True Story of a Real ...
#
#              book_author year_of_publication                      publisher
# 0  Arturo P̩rez-Reverte                2000                  Harvest Books
# 1             Steve Moss                2000  Running Press Book Publishers
# 2          Arthur Hailey                2000       Berkley Publishing Group
# 3           HAVEN KIMMEL                2002                 Broadway Books
# 4           Stan Redding                2000                       Broadway
